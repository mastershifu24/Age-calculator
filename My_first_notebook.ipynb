# %% [markdown]
# <a href="https://colab.research.google.com/github/mastershifu24/Age-calculator/blob/main/My_first_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
minutes_in_a_day = 60 * 24
minutes_in_a_day
# Out:
# 1440

# %%
minutes_in_a_week = 7 * minutes_in_a_day
minutes_in_a_week
# Out:
# 10080

# %%
import numpy as np
from matplotlib import pyplot as plt

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

plt.plot(x, ys, '-')
plt.fill_between(x, ys, 200, where=(ys > 200), facecolor = 'g', alpha = 0.6)

plt.title('Ahmed Shifa Sample Visualization')
plt.show()
